# %% [markdown]
# Importing the Libraries

# %%
import tensorflow as tf
import numpy as np
import keras
from keras.models import Sequential
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Conv2D, Dense, Dropout, MaxPooling2D, Flatten
from keras.layers import BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from skimage.transform import resize
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve, auc

# %% [markdown]
# Looading The Data

# %%
x=np.load("/content/X.npy")
y=np.load("/content/Y.npy")

# %% [markdown]
# Data Exploration

# %%
print(x)
# Out:
# [[[[226 164 206]
#    [224 154 196]
#    [225 175 211]
#    ...
#    [240 221 237]
#    [232 184 214]
#    [243 213 235]]
#
#   [[217 142 188]
#    [221 130 179]
#    [224 150 196]
#    ...
#    [227 170 204]
#    [229 180 215]
#    [236 212 232]]
#
#   [[237 178 212]
#    [229 157 199]
#    [218 125 175]
#    ...
#    [221 184 217]
#    [190 153 193]
#    [227 164 208]]
#
#   ...
#
#   [[217 145 192]
#    [214 129 184]
#    [212 129 183]
#    ...
#    [194 122 185]
#    [204 143 193]
#    [189 129 188]]
#
#   [[218 144 192]
#    [213 128 185]
#    [208 121 171]
#    ...
#    [136  79 145]
#    [184 111 174]
#    [188 112 176]]
#
#   [[212 125 181]
#    [211 136 181]
#    [220 162 206]
#    ...
#    [127  90 152]
#    [213 167 202]
#    [215 180 211]]]
#
#
#  [[[219 150 197]
#    [217 158 201]
#    [228 173 205]
#    ...
#    [198 165 199]
#    [230 204 224]
#    [231 193 221]]
#
#   [[223 150 195]
#    [222 140 192]
#    [213 133 186]
#    ...
#    [218 143 193]
#    [218 148 197]
#    [215 131 185]]
#
#   [[203 125 176]
#    [218 143 192]
#    [227 163 199]
#    ...
#    [210 137 188]
#    [203 121 177]
#    [192 124 183]]
#
#   ...
#
#   [[247 234 242]
#    [247 249 248]
#    [248 247 247]
#    ...
#    [245 240 242]
#    [249 244 247]
#    [243 234 239]]
#
#   [[249 243 246]
#    [243 240 247]
#    [248 241 246]
#    ...
#    [247 247 251]
#    [247 244 246]
#    [249 246 251]]
#
#   [[230 204 226]
#    [246 247 244]
#    [250 245 249]
#    ...
#    [249 243 250]
#    [251 248 248]
#    [248 247 247]]]
#
#
#  [[[248 245 249]
#    [248 246 248]
#    [249 246 253]
#    ...
#    [249 249 248]
#    [247 246 249]
#    [248 244 248]]
#
#   [[248 246 246]
#    [248 245 247]
#    [250 248 248]
#    ...
#    [249 243 246]
#    [252 244 247]
#    [249 250 247]]
#
#   [[241 231 238]
#    [239 225 240]
#    [243 237 242]
#    ...
#    [248 244 251]
#    [245 248 249]
#    [249 242 251]]
#
#   ...
#
#   [[248 247 249]
#    [248 247 249]
#    [248 247 249]
#    ...
#    [245 242 245]
#    [241 227 238]
#    [216 159 203]]
#
#   [[248 247 249]
#    [248 247 249]
#    [249 247 249]
#    ...
#    [249 242 249]
#    [229 193 222]
#    [161 111 171]]
#
#   [[249 247 249]
#    [249 247 249]
#    [249 247 249]
#    ...
#    [247 248 247]
#    [235 210 230]
#    [186 120 177]]]
#
#
#  ...
#
#
#  [[[241 237 240]
#    [237 238 239]
#    [216 187 207]
#    ...
#    [162 113 161]
#    [174 133 170]
#    [203 183 203]]
#
#   [[237 229 232]
#    [232 210 223]
#    [218 196 209]
#    ...
#    [153 104 149]
#    [169 118 163]
#    [215 194 208]]
#
#   [[216 182 205]
#    [235 234 236]
#    [242 239 241]
#    ...
#    [154 112 157]
#    [141 103 145]
#    [232 222 227]]
#
#   ...
#
#   [[134  79 123]
#    [142  71 113]
#    [167 106 134]
#    ...
#    [189 116 154]
#    [164  96 144]
#    [179 102 143]]
#
#   [[152  93 136]
#    [164  71 112]
#    [234 213 221]
#    ...
#    [184 113 154]
#    [176 102 144]
#    [177  97 138]]
#
#   [[139  70 118]
#    [187 124 152]
#    [239 235 238]
#    ...
#    [180 113 154]
#    [169  83 127]
#    [189 132 166]]]
#
#
#  [[[147  66 107]
#    [225 197 208]
#    [239 237 237]
#    ...
#    [180 105 147]
#    [173  85 125]
#    [178 138 173]]
#
#   [[161  95 132]
#    [240 235 237]
#    [239 236 239]
#    ...
#    [198 141 172]
#    [172  85 131]
#    [168 125 164]]
#
#   [[185 129 158]
#    [240 234 236]
#    [242 235 239]
#    ...
#    [182 119 155]
#    [175  80 126]
#    [128  85 126]]
#
#   ...
#
#   [[156  91 138]
#    [150  83 129]
#    [149  94 140]
#    ...
#    [155  91 135]
#    [152  89 137]
#    [159  75 124]]
#
#   [[187 139 175]
#    [159  97 141]
#    [160  99 147]
#    ...
#    [173 133 175]
#    [158 110 152]
#    [160 105 148]]
#
#   [[170 110 154]
#    [163 115 156]
#    [166  99 140]
#    ...
#    [149 107 149]
#    [142 102 144]
#    [148  90 142]]]
#
#
#  [[[167  99 143]
#    [155  93 138]
#    [166 105 148]
#    ...
#    [181 148 182]
#    [192 153 181]
#    [115  78 122]]
#
#   [[180 127 161]
#    [163 106 147]
#    [177 112 147]
#    ...
#    [142  99 146]
#    [150 110 155]
#    [189 151 182]]
#
#   [[163  97 144]
#    [175 113 149]
#    [173 113 153]
#    ...
#    [150  92 141]
#    [192 161 191]
#    [161 115 150]]
#
#   ...
#
#   [[147  91 140]
#    [144  95 143]
#    [151 110 154]
#    ...
#    [177 136 173]
#    [151 113 155]
#    [192 154 184]]
#
#   [[140  95 144]
#    [132  69 118]
#    [157  80 128]
#    ...
#    [202 172 197]
#    [164 128 169]
#    [194 154 187]]
#
#   [[164 121 160]
#    [137  74 124]
#    [155  84 130]
#    ...
#    [172 133 173]
#    [157 115 161]
#    [188 150 185]]]]

# %%
print(y)
# Out:
# [0 0 0 ... 1 1 1]

# %%
# Printing Shape of X and Y
print(x.shape)
print(y.shape)
# Out:
# (5547, 50, 50, 3)
# (5547,)

# %%
# Counting the Number of Images for both Classes i.e., 0 and 1
print('No of Negative Images:', len(x[y==0])) # images with label 0 = Non-IDC, Negative Images
print('No of Positive Images:', len(x[y==1])) # images with label 1 = IDC, Positive Images
# Out:
# No of Negative Images: 2759
# No of Positive Images: 2788

# %%
# Looking at some images

img0 = x[y==0] # Non-IDC, negative image
img1 = x[y==1] # IDC, positive image

batch = 0 # Each batch plot 25 Non-IDC images on the left and 25 IDC images on the right

for row in range(5):
    plt.figure(figsize=(20,10))
    for col in range(5):
        plt.subplot(1,11,col+1)
        plt.imshow(img0[9*batch + 3*row+col])
        plt.axis('off')
        plt.title('Non-IDC')
        
        plt.subplot(1,11,col+7)
        plt.imshow(img1[9*batch + 3*row+col])
        plt.axis('off')
        plt.title('IDC')

# %% [markdown]
# Data Pre-Processing

# %%
# Converting Y to 2D Array
y = np.array(y)
y = to_categorical(y)
print(y.shape)
# Out:
# (5547, 2)

# %%
# Changing Image Pixel To 64*64
x = resize(x, (5547, 64, 64, 3))
# x = resize(x, (5547, 32, 32, 3))

print(x.shape)
x
# Out:
# (5547, 64, 64, 3)
# array([[[[0.88183785, 0.62931794, 0.79588025],
#          [0.8788737 , 0.60677658, 0.77406269],
#          [0.87931028, 0.63074927, 0.78837891],
#          ...,
#          [0.92078929, 0.7764658 , 0.87390663],
#          [0.92210861, 0.75759134, 0.86610371],
#          [0.94540824, 0.82228573, 0.91146216]],
#
#         [[0.86343252, 0.58030599, 0.75641563],
#          [0.86791322, 0.55528301, 0.73583889],
#          [0.87469171, 0.57680856, 0.75287799],
#          ...,
#          [0.90417624, 0.72066387, 0.84212814],
#          [0.91259574, 0.75093922, 0.86541437],
#          [0.93093214, 0.81935604, 0.90580959]],
#
#         [[0.88590303, 0.61393708, 0.77526425],
#          [0.88273208, 0.57847063, 0.75141314],
#          [0.87494064, 0.55145144, 0.73469573],
#          ...,
#          [0.85175494, 0.6731474 , 0.81267904],
#          [0.85523706, 0.68683651, 0.82475299],
#          [0.90066445, 0.7364344 , 0.86025391]],
#
#         ...,
#
#         [[0.8513691 , 0.5596201 , 0.74974437],
#          [0.84233877, 0.52432598, 0.73330365],
#          [0.83060183, 0.49693532, 0.70930319],
#          ...,
#          [0.70241077, 0.44415116, 0.68149223],
#          [0.75117666, 0.48469765, 0.71460727],
#          [0.74100892, 0.47191042, 0.71202225]],
#
#         [[0.84559972, 0.53719458, 0.73676949],
#          [0.83746553, 0.52144321, 0.72639495],
#          [0.8319987 , 0.51905733, 0.71820523],
#          ...,
#          [0.65143421, 0.42425226, 0.65460612],
#          [0.76318742, 0.51370634, 0.72391142],
#          [0.77056334, 0.52459789, 0.73338982]],
#
#         [[0.8333295 , 0.50179707, 0.71419367],
#          [0.83015855, 0.51954753, 0.71250479],
#          [0.8415805 , 0.56968922, 0.74836378],
#          ...,
#          [0.67742226, 0.50280235, 0.69538048],
#          [0.8257104 , 0.64592142, 0.79074276],
#          [0.8306047 , 0.67170267, 0.80890682]]],
#
#
#        [[[0.85972829, 0.59082223, 0.77307847],
#          [0.85555779, 0.60412646, 0.78021312],
#          [0.86878447, 0.63426585, 0.78953929],
#          ...,
#          [0.84617034, 0.71328699, 0.82650793],
#          [0.89753753, 0.76098154, 0.86172354],
#          [0.89877834, 0.73526922, 0.85293447]],
#
#         [[0.86879308, 0.5864794 , 0.76697783],
#          [0.8658634 , 0.57744907, 0.76542682],
#          [0.85982307, 0.57257008, 0.75969095],
#          ...,
#          [0.85168505, 0.62374196, 0.78793945],
#          [0.86817172, 0.6331093 , 0.79565047],
#          [0.8644493 , 0.59995213, 0.77569413]],
#
#         [[0.84165135, 0.544964  , 0.73334961],
#          [0.85543811, 0.55089231, 0.74572323],
#          [0.86198108, 0.56365177, 0.75274682],
#          ...,
#          [0.83388385, 0.5404383 , 0.74197974],
#          [0.81972273, 0.52220052, 0.7320638 ],
#          [0.80510876, 0.50469133, 0.72358494]],
#
#         ...,
#
#         [[0.97150927, 0.93916016, 0.95899874],
#          [0.96427122, 0.95053424, 0.96620232],
#          [0.96571308, 0.95653052, 0.96862745],
#          ...,
#          [0.96896063, 0.95655733, 0.96731579],
#          [0.97009038, 0.95243949, 0.96533682],
#          [0.96650582, 0.94485677, 0.9633722 ]],
#
#         [[0.95254481, 0.90794462, 0.94179209],
#          [0.95523323, 0.93462201, 0.95630266],
#          [0.96510321, 0.95021159, 0.96648859],
#          ...,
#          [0.97260838, 0.96267616, 0.97441502],
#          [0.97423694, 0.96331667, 0.97117992],
#          [0.97502968, 0.96555702, 0.9778665 ]],
#
#         [[0.91594095, 0.83301356, 0.901776  ],
#          [0.94592716, 0.91676815, 0.93738032],
#          [0.97072132, 0.96265414, 0.96586818],
#          ...,
#          [0.97943283, 0.96350337, 0.97582816],
#          [0.97944144, 0.96996879, 0.97124885],
#          [0.97403014, 0.96848671, 0.97049058]]],
#
#
#        [[[0.97254902, 0.96154833, 0.97484873],
#          [0.97254902, 0.96327168, 0.97312538],
#          [0.97452034, 0.96486003, 0.98022748],
#          ...,
#          [0.9733542 , 0.9684015 , 0.97383578],
#          [0.97149586, 0.96240043, 0.97446672],
#          [0.97273667, 0.95991881, 0.97250211]],
#
#         [[0.97254902, 0.96327168, 0.96871362],
#          [0.97254902, 0.9625134 , 0.96947189],
#          [0.97551988, 0.96565277, 0.97402344],
#          ...,
#          [0.97938591, 0.95999157, 0.96942402],
#          [0.97963006, 0.96377911, 0.97077876],
#          [0.97590763, 0.97122396, 0.97005496]],
#
#         [[0.95972158, 0.93665077, 0.95111347],
#          [0.9577225 , 0.92944719, 0.9543189 ],
#          [0.96172066, 0.93782265, 0.95877087],
#          ...,
#          [0.9752968 , 0.95977807, 0.97281997],
#          [0.97601773, 0.96469439, 0.9733475 ],
#          [0.97639687, 0.9659352 , 0.97534658]],
#
#         ...,
#
#         [[0.97254902, 0.96862745, 0.97647059],
#          [0.97254902, 0.96862745, 0.97647059],
#          [0.9735208 , 0.96862745, 0.97647059],
#          ...,
#          [0.942019  , 0.87697419, 0.93089384],
#          [0.85693455, 0.71992762, 0.84272365],
#          [0.74991479, 0.55303883, 0.7462163 ]],
#
#         [[0.97383578, 0.96862745, 0.97647059],
#          [0.97383578, 0.96862745, 0.97647059],
#          [0.97502968, 0.96862745, 0.97647059],
#          ...,
#          [0.9366345 , 0.85939511, 0.92302964],
#          [0.82628198, 0.66984528, 0.81441291],
#          [0.69003428, 0.48317249, 0.7004653 ]],
#
#         [[0.97604167, 0.96862745, 0.97647059],
#          [0.97604167, 0.96862745, 0.97647059],
#          [0.97623602, 0.96862745, 0.97647059],
#          ...,
#          [0.94187347, 0.88590016, 0.9306813 ],
#          [0.85326957, 0.70155484, 0.83061236],
#          [0.74059723, 0.50495558, 0.71418313]]],
#
#
#        ...,
#
#
#        [[[0.94161975, 0.92547105, 0.93694087],
#          [0.93255496, 0.92285156, 0.93280484],
#          [0.89131147, 0.83788967, 0.8770278 ],
#          ...,
#          [0.65810738, 0.48076172, 0.64669979],
#          [0.71991709, 0.58313228, 0.70781633],
#          [0.78798924, 0.69969937, 0.78350567]],
#
#         [[0.93255496, 0.90299862, 0.91736366],
#          [0.92224935, 0.87556296, 0.90330116],
#          [0.88727884, 0.81310796, 0.85972541],
#          ...,
#          [0.64307981, 0.45367073, 0.62626091],
#          [0.72119236, 0.56886297, 0.70106081],
#          [0.81035826, 0.7176911 , 0.79163986]],
#
#         [[0.8946155 , 0.82017176, 0.86573989],
#          [0.90757506, 0.84922737, 0.88586857],
#          [0.90716625, 0.85659754, 0.88803136],
#          ...,
#          [0.6079092 , 0.4297325 , 0.60328776],
#          [0.69841931, 0.55895661, 0.68670822],
#          [0.84486922, 0.76958391, 0.82295592]],
#
#         ...,
#
#         [[0.56846278, 0.33311313, 0.5026597 ],
#          [0.5909352 , 0.29857728, 0.46371209],
#          [0.69219803, 0.44460497, 0.56382506],
#          ...,
#          [0.69677639, 0.41613147, 0.58247549],
#          [0.67832223, 0.38931813, 0.55990062],
#          [0.69452168, 0.38928366, 0.55166303]],
#
#         [[0.58956419, 0.33637025, 0.50804036],
#          [0.64209176, 0.34285003, 0.49707989],
#          [0.78662492, 0.58088331, 0.6709645 ],
#          ...,
#          [0.69715361, 0.40617628, 0.5705126 ],
#          [0.69049766, 0.39191751, 0.55411018],
#          [0.70645584, 0.41997358, 0.57344612]],
#
#         [[0.56957338, 0.30397135, 0.48232805],
#          [0.66677007, 0.4047526 , 0.54333448],
#          [0.81936849, 0.66680932, 0.73621036],
#          ...,
#          [0.68471105, 0.38325578, 0.55000479],
#          [0.68880879, 0.38909122, 0.54918141],
#          [0.72834233, 0.48415097, 0.62435375]]],
#
#
#        [[[0.61597829, 0.3278732 , 0.47383961],
#          [0.78827838, 0.6190152 , 0.69759881],
#          [0.91074889, 0.85234662, 0.87440928],
#          ...,
#          [0.69413392, 0.37586933, 0.53555549],
#          [0.68316962, 0.39970224, 0.55242322],
#          [0.69202761, 0.51347752, 0.65468654]],
#
#         [[0.64710191, 0.3940152 , 0.52995175],
#          [0.82064281, 0.69632449, 0.75867417],
#          [0.92884402, 0.89718807, 0.91139227],
#          ...,
#          [0.71091931, 0.41185279, 0.56778205],
#          [0.67444949, 0.39029278, 0.55480143],
#          [0.6721402 , 0.48793754, 0.63845263]],
#
#         [[0.70323989, 0.48621228, 0.60363722],
#          [0.85351562, 0.76005189, 0.80826727],
#          [0.94181507, 0.92156863, 0.93199391],
#          ...,
#          [0.71074314, 0.41027018, 0.56803385],
#          [0.64962182, 0.35551183, 0.52806277],
#          [0.59781805, 0.40876321, 0.56787205]],
#
#         ...,
#
#         [[0.67051356, 0.44839729, 0.6108025 ],
#          [0.63073874, 0.3897346 , 0.56079102],
#          [0.60770335, 0.3663153 , 0.54630534],
#          ...,
#          [0.62593827, 0.41801758, 0.59016448],
#          [0.61443493, 0.38237496, 0.55902937],
#          [0.6238444 , 0.36234969, 0.54120998]],
#
#         [[0.70240407, 0.49638193, 0.64973575],
#          [0.65583927, 0.43775371, 0.60079274],
#          [0.63161956, 0.39661267, 0.57007698],
#          ...,
#          [0.6210095 , 0.45145335, 0.61615924],
#          [0.60328202, 0.41168907, 0.58148169],
#          [0.610589  , 0.39559302, 0.57410578]],
#
#         [[0.6699707 , 0.44375096, 0.61209789],
#          [0.64946289, 0.44344076, 0.60782399],
#          [0.64244217, 0.41832682, 0.58117532],
#          ...,
#          [0.57771906, 0.41581457, 0.58052045],
#          [0.57088312, 0.38897538, 0.56528225],
#          [0.58315334, 0.36419367, 0.56038794]]],
#
#
#        [[[0.65509632, 0.39696787, 0.56593807],
#          [0.62741939, 0.38011355, 0.55273725],
#          [0.63140414, 0.39043926, 0.56086282],
#          ...,
#          [0.71596297, 0.57150544, 0.69848537],
#          [0.65217142, 0.50137485, 0.63483647],
#          [0.51030561, 0.3639208 , 0.5254385 ]],
#
#         [[0.68256644, 0.45511355, 0.60347254],
#          [0.64868547, 0.4196471 , 0.57910443],
#          [0.65204982, 0.41311849, 0.57072036],
#          ...,
#          [0.62631453, 0.47065525, 0.63113703],
#          [0.64348575, 0.4904833 , 0.63973078],
#          [0.64555377, 0.49696308, 0.63704236]],
#
#         [[0.67401865, 0.44291418, 0.59885206],
#          [0.66550532, 0.43357364, 0.58696098],
#          [0.6725337 , 0.43395565, 0.58324525],
#          ...,
#          [0.62127566, 0.45575023, 0.62280848],
#          [0.6722369 , 0.52402822, 0.66690794],
#          [0.68829848, 0.52750938, 0.65849801]],
#
#         ...,
#
#         [[0.55899874, 0.36011987, 0.55208238],
#          [0.54634938, 0.33275314, 0.52371611],
#          [0.56890127, 0.33955653, 0.52574391],
#          ...,
#          [0.67789905, 0.53658375, 0.6795707 ],
#          [0.66505342, 0.51750823, 0.66744313],
#          [0.74222484, 0.58985428, 0.71814396]],
#
#         [[0.57379653, 0.3918974 , 0.57273476],
#          [0.54239717, 0.31934455, 0.50814377],
#          [0.56442345, 0.29598556, 0.48590303],
#          ...,
#          [0.68824391, 0.54825942, 0.69287684],
#          [0.67315506, 0.5224887 , 0.67814606],
#          [0.74005534, 0.58635589, 0.72219478]],
#
#         [[0.62215361, 0.44418371, 0.60561619],
#          [0.56717888, 0.34557387, 0.52861711],
#          [0.56845607, 0.30601543, 0.49514017],
#          ...,
#          [0.6498133 , 0.4935949 , 0.65923713],
#          [0.65843769, 0.50032648, 0.66484184],
#          [0.72657878, 0.57536095, 0.7163354 ]]]])

# %%
# Splitting Data into Training And Testing Set
seed = 1234
np.random.seed(seed)
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# Building Models

# %%
# Model-2
model2 = Sequential()
model2.add(Conv2D(filters=32, kernel_size=(3, 3), input_shape=(64, 64, 3), activation='relu'))
model2.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model2.add(Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
model2.add(Conv2D(filters=256,kernel_size=(3,3), activation = 'relu'))
model2.add(Conv2D(filters=256,kernel_size=(3,3), activation = 'relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(Conv2D(filters=512,kernel_size=(3,3), activation = 'relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(Flatten())
model2.add(Dense(2, activation='sigmoid')) 

model2.compile(optimizer=tf.keras.optimizers.Adam(0.000005),
             loss='binary_crossentropy',
             metrics=['accuracy'])
print(model2.summary())

callback = EarlyStopping(monitor='val_accuracy', patience=5)

seed = 1234
np.random.seed(seed)
history2 = model2.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=32, callbacks=[callback])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 60, 60, 64)        18496
#
#  conv2d_2 (Conv2D)           (None, 58, 58, 128)       73856
#
#  conv2d_3 (Conv2D)           (None, 56, 56, 256)       295168
#
#  conv2d_4 (Conv2D)           (None, 54, 54, 256)       590080
#
#  max_pooling2d (MaxPooling2D  (None, 27, 27, 256)      0
#  )
#
#  conv2d_5 (Conv2D)           (None, 25, 25, 512)       1180160
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 512)      0
#  2D)
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 2)                 147458
#
# =================================================================
# Total params: 2,306,114
# Trainable params: 2,306,114
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 139/139 [==============================] - 30s 120ms/step - loss: 0.6912 - accuracy: 0.5310 - val_loss: 0.6871 - val_accuracy: 0.5099
# Epoch 2/50
# 139/139 [==============================] - 15s 105ms/step - loss: 0.6737 - accuracy: 0.6108 - val_loss: 0.6445 - val_accuracy: 0.7054
# Epoch 3/50
# 139/139 [==============================] - 15s 108ms/step - loss: 0.5892 - accuracy: 0.7190 - val_loss: 0.5771 - val_accuracy: 0.7000
# Epoch 4/50
# 139/139 [==============================] - 15s 111ms/step - loss: 0.5536 - accuracy: 0.7413 - val_loss: 0.5746 - val_accuracy: 0.6964
# Epoch 5/50
# 139/139 [==============================] - 16s 116ms/step - loss: 0.5460 - accuracy: 0.7415 - val_loss: 0.5570 - val_accuracy: 0.7234
# Epoch 6/50
# 139/139 [==============================] - 17s 120ms/step - loss: 0.5383 - accuracy: 0.7446 - val_loss: 0.5463 - val_accuracy: 0.7333
# Epoch 7/50
# 139/139 [==============================] - 16s 117ms/step - loss: 0.5310 - accuracy: 0.7519 - val_loss: 0.5447 - val_accuracy: 0.7279
# Epoch 8/50
# 139/139 [==============================] - 16s 114ms/step - loss: 0.5295 - accuracy: 0.7483 - val_loss: 0.5413 - val_accuracy: 0.7360
# Epoch 9/50
# 139/139 [==============================] - 16s 113ms/step - loss: 0.5255 - accuracy: 0.7546 - val_loss: 0.5392 - val_accuracy: 0.7369
# Epoch 10/50
# 139/139 [==============================] - 16s 114ms/step - loss: 0.5238 - accuracy: 0.7525 - val_loss: 0.5410 - val_accuracy: 0.7378
# Epoch 11/50
# 139/139 [==============================] - 16s 116ms/step - loss: 0.5218 - accuracy: 0.7510 - val_loss: 0.5331 - val_accuracy: 0.7396
# Epoch 12/50
# 139/139 [==============================] - 16s 116ms/step - loss: 0.5197 - accuracy: 0.7555 - val_loss: 0.5319 - val_accuracy: 0.7387
# Epoch 13/50
# 139/139 [==============================] - 16s 116ms/step - loss: 0.5204 - accuracy: 0.7510 - val_loss: 0.5304 - val_accuracy: 0.7405
# Epoch 14/50
# 139/139 [==============================] - 16s 117ms/step - loss: 0.5157 - accuracy: 0.7555 - val_loss: 0.5305 - val_accuracy: 0.7423
# Epoch 15/50
# 139/139 [==============================] - 17s 125ms/step - loss: 0.5137 - accuracy: 0.7561 - val_loss: 0.5273 - val_accuracy: 0.7432
# Epoch 16/50
# 139/139 [==============================] - 16s 116ms/step - loss: 0.5122 - accuracy: 0.7591 - val_loss: 0.5251 - val_accuracy: 0.7414
# Epoch 17/50
# 139/139 [==============================] - 16s 116ms/step - loss: 0.5126 - accuracy: 0.7600 - val_loss: 0.5244 - val_accuracy: 0.7459
# Epoch 18/50
# 139/139 [==============================] - 16s 115ms/step - loss: 0.5077 - accuracy: 0.7602 - val_loss: 0.5225 - val_accuracy: 0.7468
# Epoch 19/50
# 139/139 [==============================] - 16s 115ms/step - loss: 0.5093 - accuracy: 0.7595 - val_loss: 0.5216 - val_accuracy: 0.7432
# Epoch 20/50
# 139/139 [==============================] - 16s 117ms/step - loss: 0.5073 - accuracy: 0.7595 - val_loss: 0.5251 - val_accuracy: 0.7495
# Epoch 21/50
# 139/139 [==============================] - 16s 117ms/step - loss: 0.5073 - accuracy: 0.7591 - val_loss: 0.5301 - val_accuracy: 0.7477
# Epoch 22/50
# 139/139 [==============================] - 16s 116ms/step - loss: 0.5037 - accuracy: 0.7631 - val_loss: 0.5188 - val_accuracy: 0.7459
# Epoch 23/50
# 139/139 [==============================] - 16s 116ms/step - loss: 0.5032 - accuracy: 0.7638 - val_loss: 0.5181 - val_accuracy: 0.7459
# Epoch 24/50
# 139/139 [==============================] - 16s 117ms/step - loss: 0.5027 - accuracy: 0.7616 - val_loss: 0.5184 - val_accuracy: 0.7495
# Epoch 25/50
# 139/139 [==============================] - 16s 117ms/step - loss: 0.5040 - accuracy: 0.7613 - val_loss: 0.5168 - val_accuracy: 0.7505
# Epoch 26/50
# 139/139 [==============================] - 16s 117ms/step - loss: 0.5004 - accuracy: 0.7604 - val_loss: 0.5327 - val_accuracy: 0.7414
# Epoch 27/50
# 139/139 [==============================] - 16s 116ms/step - loss: 0.5008 - accuracy: 0.7647 - val_loss: 0.5157 - val_accuracy: 0.7495
# Epoch 28/50
# 139/139 [==============================] - 16s 117ms/step - loss: 0.4986 - accuracy: 0.7634 - val_loss: 0.5162 - val_accuracy: 0.7514
# Epoch 29/50
# 139/139 [==============================] - 16s 116ms/step - loss: 0.4968 - accuracy: 0.7629 - val_loss: 0.5165 - val_accuracy: 0.7477
# Epoch 30/50
# 139/139 [==============================] - 16s 116ms/step - loss: 0.4956 - accuracy: 0.7645 - val_loss: 0.5126 - val_accuracy: 0.7523
# Epoch 31/50
# 139/139 [==============================] - 16s 116ms/step - loss: 0.4945 - accuracy: 0.7643 - val_loss: 0.5167 - val_accuracy: 0.7477
# Epoch 32/50
# 139/139 [==============================] - 18s 126ms/step - loss: 0.4959 - accuracy: 0.7645 - val_loss: 0.5207 - val_accuracy: 0.7450
# Epoch 33/50
# 139/139 [==============================] - 16s 117ms/step - loss: 0.4957 - accuracy: 0.7618 - val_loss: 0.5170 - val_accuracy: 0.7514
# Epoch 34/50
# 139/139 [==============================] - 16s 117ms/step - loss: 0.4935 - accuracy: 0.7663 - val_loss: 0.5115 - val_accuracy: 0.7559
# Epoch 35/50
# 139/139 [==============================] - 16s 118ms/step - loss: 0.4932 - accuracy: 0.7663 - val_loss: 0.5101 - val_accuracy: 0.7559
# Epoch 36/50
# 139/139 [==============================] - 16s 117ms/step - loss: 0.4906 - accuracy: 0.7656 - val_loss: 0.5145 - val_accuracy: 0.7495
# Epoch 37/50
# 139/139 [==============================] - 16s 117ms/step - loss: 0.4909 - accuracy: 0.7683 - val_loss: 0.5154 - val_accuracy: 0.7486
# Epoch 38/50
# 139/139 [==============================] - 16s 116ms/step - loss: 0.4908 - accuracy: 0.7676 - val_loss: 0.5189 - val_accuracy: 0.7523
# Epoch 39/50
# 139/139 [==============================] - 16s 116ms/step - loss: 0.4894 - accuracy: 0.7708 - val_loss: 0.5129 - val_accuracy: 0.7505

# %%
# test the classifier model:
preds=model2.predict(X_test)
preds
# Out:
# array([[0.76801157, 0.24130152],
#        [0.20290835, 0.8026069 ],
#        [0.5614087 , 0.4356271 ],
#        ...,
#        [0.32654718, 0.66324943],
#        [0.11382664, 0.8896676 ],
#        [0.08171489, 0.91751486]], dtype=float32)

# %%
y_test_arg=np.argmax(y_test,axis=1)
Y_pred = np.argmax(preds,axis=1)
print(confusion_matrix(y_test_arg, Y_pred))
print(classification_report(y_test_arg, Y_pred))
# Out:
# [[411 155]
#  [122 422]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.73      0.75       566
#            1       0.73      0.78      0.75       544
#
#     accuracy                           0.75      1110
#    macro avg       0.75      0.75      0.75      1110
# weighted avg       0.75      0.75      0.75      1110

# %%
import matplotlib.pyplot as plt
# summarize history for accuracy
plt.plot(history2.history['accuracy'])
plt.plot(history2.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
# Compute ROC curve and ROC area for each class

y_score = model2.predict(X_test) # get the prediction probabilities

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(2):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
# Plot of a ROC curve for a specific class
for i in range(2):
    plt.figure()
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % roc_auc[i])
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.show()

# %%
# Model-4
model4 = Sequential() 

model4.add(Conv2D(64,(3,3), activation = 'relu', padding = 'same', input_shape = (64,64,3)))
model4.add(MaxPooling2D(pool_size=(2,2)))
model4.add(Dropout(0.20))
model4.add(Conv2D(128,(3,3), activation = 'relu', padding = 'same'))
model4.add(Dropout(0.25))
model4.add(Conv2D(256,(3,3), activation = 'relu', padding = 'same'))
model4.add(MaxPooling2D(pool_size=(2,2)))
model4.add(Dropout(0.25))
model4.add(Conv2D(512,(3,3), activation = 'relu', padding = 'same'))
model4.add(Dropout(0.25))
model4.add(Conv2D(1024,(3,3), activation = 'relu', padding = 'same'))
model4.add(MaxPooling2D(pool_size=(2,2)))
model4.add(Flatten())
model4.add(Dense(2, activation = 'sigmoid'))


model4.summary()
model4.compile(loss='binary_crossentropy', optimizer ='RMSprop', metrics=['accuracy'])

callback = EarlyStopping(monitor='val_accuracy', patience=5)

seed = 1234
np.random.seed(seed)
history4 = model4.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=32, callbacks=[callback])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 64, 64, 64)        1792
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 32, 32, 64)        0
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 128)       73856
#
#  dropout_1 (Dropout)         (None, 32, 32, 128)       0
#
#  conv2d_8 (Conv2D)           (None, 32, 32, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 256)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 16, 16, 256)       0
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 512)       1180160
#
#  dropout_3 (Dropout)         (None, 16, 16, 512)       0
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 1024)      4719616
#
#  max_pooling2d_4 (MaxPooling  (None, 8, 8, 1024)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 65536)             0
#
#  dense_1 (Dense)             (None, 2)                 131074
#
# =================================================================
# Total params: 6,401,666
# Trainable params: 6,401,666
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 139/139 [==============================] - 11s 62ms/step - loss: 0.8360 - accuracy: 0.5418 - val_loss: 0.6972 - val_accuracy: 0.4901
# Epoch 2/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.6978 - accuracy: 0.5659 - val_loss: 0.6920 - val_accuracy: 0.4901
# Epoch 3/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.6685 - accuracy: 0.6322 - val_loss: 0.6421 - val_accuracy: 0.6261
# Epoch 4/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.6098 - accuracy: 0.6953 - val_loss: 0.5744 - val_accuracy: 0.7117
# Epoch 5/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.5808 - accuracy: 0.7025 - val_loss: 0.5450 - val_accuracy: 0.7568
# Epoch 6/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.5663 - accuracy: 0.7277 - val_loss: 0.5615 - val_accuracy: 0.7360
# Epoch 7/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.5524 - accuracy: 0.7250 - val_loss: 0.6229 - val_accuracy: 0.6387
# Epoch 8/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.5483 - accuracy: 0.7354 - val_loss: 0.5185 - val_accuracy: 0.7532
# Epoch 9/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.5297 - accuracy: 0.7498 - val_loss: 0.5234 - val_accuracy: 0.7532
# Epoch 10/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.5228 - accuracy: 0.7465 - val_loss: 0.5784 - val_accuracy: 0.7261

# %%
# test the classifier model:
preds=model4.predict(X_test)
preds
# Out:
# array([[0.37812126, 0.616792  ],
#        [0.12779768, 0.87218815],
#        [0.39385366, 0.6049992 ],
#        ...,
#        [0.12660432, 0.87220573],
#        [0.10988078, 0.8914451 ],
#        [0.04626908, 0.9534639 ]], dtype=float32)

# %%
y_test_arg=np.argmax(y_test,axis=1)
Y_pred = np.argmax(preds,axis=1)
print(confusion_matrix(y_test_arg, Y_pred))
print(classification_report(y_test_arg, Y_pred))
# Out:
# [[314 252]
#  [ 52 492]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.55      0.67       566
#            1       0.66      0.90      0.76       544
#
#     accuracy                           0.73      1110
#    macro avg       0.76      0.73      0.72      1110
# weighted avg       0.76      0.73      0.72      1110

# %%
# summarize history for accuracy
plt.plot(history4.history['accuracy'])
plt.plot(history4.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history4.history['loss'])
plt.plot(history4.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
# Compute ROC curve and ROC area for each class

y_score = model4.predict(X_test) # get the prediction probabilities

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(2):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
# Plot of a ROC curve for a specific class
for i in range(2):
    plt.figure()
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % roc_auc[i])
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# Fine-Tuned Models

# %%
#  Model-5
model5 = Sequential()
model5.add(Conv2D(32,(3,3), activation = 'relu', padding = 'same', input_shape = (64,64,3)))
model5.add(Conv2D(32,(3,3), activation = 'relu', padding = 'same'))
model5.add(MaxPooling2D(pool_size=(2,2)))
model5.add(Dropout(0.25))
model5.add(Conv2D(64,(3,3), activation = 'relu', padding = 'same'))
model5.add(Conv2D(64,(3,3), activation = 'relu', padding = 'same'))
model5.add(MaxPooling2D(pool_size=(2,2)))
model5.add(Dropout(0.25))
model5.add(Flatten())
model5.add(Dense(512, activation = 'relu'))
model5.add(Dropout(0.5))
model5.add(Dense(2, activation = 'softmax'))


model5.compile(optimizer='adam',
             loss= "binary_crossentropy",
             metrics=['accuracy'])
print(model5.summary())

callback = EarlyStopping(monitor='val_accuracy', patience=5)

seed = 1234
np.random.seed(seed)
history5 = model5.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test), verbose = 1, callbacks=[callback])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_11 (Conv2D)          (None, 64, 64, 32)        896
#
#  conv2d_12 (Conv2D)          (None, 64, 64, 32)        9248
#
#  max_pooling2d_5 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  dropout_4 (Dropout)         (None, 32, 32, 32)        0
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 64)        18496
#
#  conv2d_14 (Conv2D)          (None, 32, 32, 64)        36928
#
#  max_pooling2d_6 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 16, 16, 64)        0
#
#  flatten_2 (Flatten)         (None, 16384)             0
#
#  dense_2 (Dense)             (None, 512)               8389120
#
#  dropout_6 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 8,455,714
# Trainable params: 8,455,714
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 139/139 [==============================] - 3s 17ms/step - loss: 0.6602 - accuracy: 0.6225 - val_loss: 0.7158 - val_accuracy: 0.5685
# Epoch 2/50
# 139/139 [==============================] - 2s 14ms/step - loss: 0.5938 - accuracy: 0.6975 - val_loss: 0.5336 - val_accuracy: 0.7423
# Epoch 3/50
# 139/139 [==============================] - 2s 15ms/step - loss: 0.5375 - accuracy: 0.7474 - val_loss: 0.5238 - val_accuracy: 0.7631
# Epoch 4/50
# 139/139 [==============================] - 2s 15ms/step - loss: 0.5124 - accuracy: 0.7613 - val_loss: 0.5109 - val_accuracy: 0.7640
# Epoch 5/50
# 139/139 [==============================] - 2s 15ms/step - loss: 0.5160 - accuracy: 0.7570 - val_loss: 0.5236 - val_accuracy: 0.7432
# Epoch 6/50
# 139/139 [==============================] - 2s 15ms/step - loss: 0.5030 - accuracy: 0.7640 - val_loss: 0.5169 - val_accuracy: 0.7523
# Epoch 7/50
# 139/139 [==============================] - 2s 15ms/step - loss: 0.5076 - accuracy: 0.7636 - val_loss: 0.5215 - val_accuracy: 0.7577
# Epoch 8/50
# 139/139 [==============================] - 2s 15ms/step - loss: 0.4949 - accuracy: 0.7728 - val_loss: 0.5567 - val_accuracy: 0.7270
# Epoch 9/50
# 139/139 [==============================] - 2s 15ms/step - loss: 0.4908 - accuracy: 0.7724 - val_loss: 0.5076 - val_accuracy: 0.7577

# %%
# test the classifier model:
preds=model5.predict(X_test)
preds
# Out:
# array([[0.98798484, 0.0120151 ],
#        [0.06726677, 0.93273324],
#        [0.65147537, 0.34852463],
#        ...,
#        [0.13907704, 0.860923  ],
#        [0.08902612, 0.91097385],
#        [0.02185649, 0.9781436 ]], dtype=float32)

# %%
y_test_arg=np.argmax(y_test,axis=1)
Y_pred = np.argmax(preds,axis=1)
print(confusion_matrix(y_test_arg, Y_pred))
print(classification_report(y_test_arg, Y_pred))
# Out:
# [[393 173]
#  [ 96 448]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.75       566
#            1       0.72      0.82      0.77       544
#
#     accuracy                           0.76      1110
#    macro avg       0.76      0.76      0.76      1110
# weighted avg       0.76      0.76      0.76      1110

# %%
# import matplotlib.pyplot as plt
# summarize history for accuracy
plt.plot(history5.history['accuracy'])
plt.plot(history5.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history5.history['loss'])
plt.plot(history5.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
# Compute ROC curve and ROC area for each class

y_score = model5.predict(X_test) # get the prediction probabilities

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(2):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
# Plot of a ROC curve for a specific class
for i in range(2):
    plt.figure()
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % roc_auc[i])
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.show()

# %%
# Model-9
model9 = Sequential() 

model9.add(Conv2D(64,(3,3), activation = 'relu', padding = 'same', input_shape = (64,64,3)))
model9.add(MaxPooling2D(pool_size=(2,2)))
model9.add(Dropout(0.20))
model9.add(Conv2D(128,(3,3), activation = 'relu', padding = 'same'))
model9.add(Dropout(0.25))
model9.add(Conv2D(256,(3,3), activation = 'relu', padding = 'same'))
model9.add(MaxPooling2D(pool_size=(2,2)))
model9.add(Dropout(0.25))
model9.add(Conv2D(512,(3,3), activation = 'relu', padding = 'same'))
model9.add(Dropout(0.25))
model9.add(Conv2D(1024,(3,3), activation = 'relu', padding = 'same'))
model9.add(MaxPooling2D(pool_size=(2,2)))
model9.add(Flatten())
model9.add(Dense(2, activation = 'softmax'))


model9.summary()
model9.compile(loss='binary_crossentropy', optimizer ='RMSprop', metrics=['accuracy'])

callback = EarlyStopping(monitor='val_accuracy', patience=5)

seed = 1234
np.random.seed(seed)
history9 = model9.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=32, callbacks=[callback])
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 64, 64, 64)        1792
#
#  max_pooling2d_7 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  dropout_7 (Dropout)         (None, 32, 32, 64)        0
#
#  conv2d_16 (Conv2D)          (None, 32, 32, 128)       73856
#
#  dropout_8 (Dropout)         (None, 32, 32, 128)       0
#
#  conv2d_17 (Conv2D)          (None, 32, 32, 256)       295168
#
#  max_pooling2d_8 (MaxPooling  (None, 16, 16, 256)      0
#  2D)
#
#  dropout_9 (Dropout)         (None, 16, 16, 256)       0
#
#  conv2d_18 (Conv2D)          (None, 16, 16, 512)       1180160
#
#  dropout_10 (Dropout)        (None, 16, 16, 512)       0
#
#  conv2d_19 (Conv2D)          (None, 16, 16, 1024)      4719616
#
#  max_pooling2d_9 (MaxPooling  (None, 8, 8, 1024)       0
#  2D)
#
#  flatten_3 (Flatten)         (None, 65536)             0
#
#  dense_4 (Dense)             (None, 2)                 131074
#
# =================================================================
# Total params: 6,401,666
# Trainable params: 6,401,666
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 139/139 [==============================] - 8s 52ms/step - loss: 2.0312 - accuracy: 0.5501 - val_loss: 0.6944 - val_accuracy: 0.4901
# Epoch 2/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.6990 - accuracy: 0.6297 - val_loss: 0.5600 - val_accuracy: 0.7198
# Epoch 3/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.6410 - accuracy: 0.6748 - val_loss: 0.6524 - val_accuracy: 0.6514
# Epoch 4/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.6106 - accuracy: 0.6962 - val_loss: 0.5639 - val_accuracy: 0.7405
# Epoch 5/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.5850 - accuracy: 0.7144 - val_loss: 0.5293 - val_accuracy: 0.7477
# Epoch 6/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.5683 - accuracy: 0.7212 - val_loss: 0.6275 - val_accuracy: 0.6261
# Epoch 7/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.5523 - accuracy: 0.7253 - val_loss: 0.5105 - val_accuracy: 0.7577
# Epoch 8/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.5342 - accuracy: 0.7469 - val_loss: 0.6535 - val_accuracy: 0.6577
# Epoch 9/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.5286 - accuracy: 0.7573 - val_loss: 0.5165 - val_accuracy: 0.7577
# Epoch 10/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.5562 - accuracy: 0.7550 - val_loss: 0.5168 - val_accuracy: 0.7586
# Epoch 11/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.5248 - accuracy: 0.7643 - val_loss: 0.5097 - val_accuracy: 0.7631
# Epoch 12/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.5042 - accuracy: 0.7690 - val_loss: 0.5076 - val_accuracy: 0.7514
# Epoch 13/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.5641 - accuracy: 0.7636 - val_loss: 0.5880 - val_accuracy: 0.7108
# Epoch 14/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.4900 - accuracy: 0.7778 - val_loss: 0.5386 - val_accuracy: 0.7477
# Epoch 15/50
# 139/139 [==============================] - 7s 51ms/step - loss: 0.5513 - accuracy: 0.7753 - val_loss: 0.5698 - val_accuracy: 0.7523
# Epoch 16/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.5261 - accuracy: 0.7818 - val_loss: 0.6071 - val_accuracy: 0.7252

# %%
# test the classifier model:
preds=model9.predict(X_test)
preds
# Out:
# array([[0.9975625 , 0.0024375 ],
#        [0.4938394 , 0.5061606 ],
#        [0.98917794, 0.01082206],
#        ...,
#        [0.8387921 , 0.16120793],
#        [0.68340135, 0.31659862],
#        [0.01765275, 0.98234725]], dtype=float32)

# %%
y_test_arg=np.argmax(y_test,axis=1)
Y_pred = np.argmax(preds,axis=1)
print(confusion_matrix(y_test_arg, Y_pred))
print(classification_report(y_test_arg, Y_pred))
# Out:
# [[498  68]
#  [237 307]]
#               precision    recall  f1-score   support
#
#            0       0.68      0.88      0.77       566
#            1       0.82      0.56      0.67       544
#
#     accuracy                           0.73      1110
#    macro avg       0.75      0.72      0.72      1110
# weighted avg       0.75      0.73      0.72      1110

# %%
plt.plot(history9.history['accuracy'])
plt.plot(history9.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history9.history['loss'])
plt.plot(history9.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
# Compute ROC curve and ROC area for each class

y_score = model9.predict(X_test) # get the prediction probabilities

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(2):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
# Plot of a ROC curve for a specific class
for i in range(2):
    plt.figure()
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % roc_auc[i])
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# Pre-Trained Models

# %%
EfficientNetB7=tf.keras.applications.efficientnet.EfficientNetB7(input_shape=(64,64,3),
                                               include_top=False,
                                               weights='imagenet')
mod1=EfficientNetB7.output
mod1=tf.keras.layers.Flatten()(mod1)
mod1=tf.keras.layers.Dense(units=512, activation=tf.nn.relu)(mod1)
output1=tf.keras.layers.Dense(units=2, activation=tf.nn.softmax)(mod1)
model= tf.keras.models.Model(inputs=EfficientNetB7.inputs,outputs=output1)

model.compile(optimizer=tf.keras.optimizers.Adam(0.0005),
             loss=tf.keras.losses.BinaryCrossentropy(from_logits= False),
             metrics=['accuracy'])
model.summary()

callback = EarlyStopping(monitor='val_accuracy', patience=5)

seed = 1234
np.random.seed(seed)
hist = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=32, callbacks=[callback])
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb7_notop.h5
# 258080768/258076736 [==============================] - 1s 0us/step
# 258088960/258076736 [==============================] - 1s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  rescaling (Rescaling)          (None, 64, 64, 3)    0           ['input_1[0][0]']
#
#  normalization (Normalization)  (None, 64, 64, 3)    7           ['rescaling[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 65, 65, 3)    0           ['normalization[0][0]']
#
#  stem_conv (Conv2D)             (None, 32, 32, 64)   1728        ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalization)   (None, 32, 32, 64)   256         ['stem_conv[0][0]']
#
#  stem_activation (Activation)   (None, 32, 32, 64)   0           ['stem_bn[0][0]']
#
#  block1a_dwconv (DepthwiseConv2  (None, 32, 32, 64)  576         ['stem_activation[0][0]']
#  D)
#
#  block1a_bn (BatchNormalization  (None, 32, 32, 64)  256         ['block1a_dwconv[0][0]']
#  )
#
#  block1a_activation (Activation  (None, 32, 32, 64)  0           ['block1a_bn[0][0]']
#  )
#
#  block1a_se_squeeze (GlobalAver  (None, 64)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 64)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 16)     1040        ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 64)     1088        ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 32, 32, 64)   0           ['block1a_activation[0][0]',
#                                                                   'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 32, 32, 32)   2048        ['block1a_se_excite[0][0]']
#
#  block1a_project_bn (BatchNorma  (None, 32, 32, 32)  128         ['block1a_project_conv[0][0]']
#  lization)
#
#  block1b_dwconv (DepthwiseConv2  (None, 32, 32, 32)  288         ['block1a_project_bn[0][0]']
#  D)
#
#  block1b_bn (BatchNormalization  (None, 32, 32, 32)  128         ['block1b_dwconv[0][0]']
#  )
#
#  block1b_activation (Activation  (None, 32, 32, 32)  0           ['block1b_bn[0][0]']
#  )
#
#  block1b_se_squeeze (GlobalAver  (None, 32)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 32, 32, 32)   0           ['block1b_activation[0][0]',
#                                                                   'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 32, 32, 32)   1024        ['block1b_se_excite[0][0]']
#
#  block1b_project_bn (BatchNorma  (None, 32, 32, 32)  128         ['block1b_project_conv[0][0]']
#  lization)
#
#  block1b_drop (Dropout)         (None, 32, 32, 32)   0           ['block1b_project_bn[0][0]']
#
#  block1b_add (Add)              (None, 32, 32, 32)   0           ['block1b_drop[0][0]',
#                                                                   'block1a_project_bn[0][0]']
#
#  block1c_dwconv (DepthwiseConv2  (None, 32, 32, 32)  288         ['block1b_add[0][0]']
#  D)
#
#  block1c_bn (BatchNormalization  (None, 32, 32, 32)  128         ['block1c_dwconv[0][0]']
#  )
#
#  block1c_activation (Activation  (None, 32, 32, 32)  0           ['block1c_bn[0][0]']
#  )
#
#  block1c_se_squeeze (GlobalAver  (None, 32)          0           ['block1c_activation[0][0]']
#  agePooling2D)
#
#  block1c_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1c_se_squeeze[0][0]']
#
#  block1c_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1c_se_reshape[0][0]']
#
#  block1c_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1c_se_reduce[0][0]']
#
#  block1c_se_excite (Multiply)   (None, 32, 32, 32)   0           ['block1c_activation[0][0]',
#                                                                   'block1c_se_expand[0][0]']
#
#  block1c_project_conv (Conv2D)  (None, 32, 32, 32)   1024        ['block1c_se_excite[0][0]']
#
#  block1c_project_bn (BatchNorma  (None, 32, 32, 32)  128         ['block1c_project_conv[0][0]']
#  lization)
#
#  block1c_drop (Dropout)         (None, 32, 32, 32)   0           ['block1c_project_bn[0][0]']
#
#  block1c_add (Add)              (None, 32, 32, 32)   0           ['block1c_drop[0][0]',
#                                                                   'block1b_add[0][0]']
#
#  block1d_dwconv (DepthwiseConv2  (None, 32, 32, 32)  288         ['block1c_add[0][0]']
#  D)
#
#  block1d_bn (BatchNormalization  (None, 32, 32, 32)  128         ['block1d_dwconv[0][0]']
#  )
#
#  block1d_activation (Activation  (None, 32, 32, 32)  0           ['block1d_bn[0][0]']
#  )
#
#  block1d_se_squeeze (GlobalAver  (None, 32)          0           ['block1d_activation[0][0]']
#  agePooling2D)
#
#  block1d_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1d_se_squeeze[0][0]']
#
#  block1d_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1d_se_reshape[0][0]']
#
#  block1d_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1d_se_reduce[0][0]']
#
#  block1d_se_excite (Multiply)   (None, 32, 32, 32)   0           ['block1d_activation[0][0]',
#                                                                   'block1d_se_expand[0][0]']
#
#  block1d_project_conv (Conv2D)  (None, 32, 32, 32)   1024        ['block1d_se_excite[0][0]']
#
#  block1d_project_bn (BatchNorma  (None, 32, 32, 32)  128         ['block1d_project_conv[0][0]']
#  lization)
#
#  block1d_drop (Dropout)         (None, 32, 32, 32)   0           ['block1d_project_bn[0][0]']
#
#  block1d_add (Add)              (None, 32, 32, 32)   0           ['block1d_drop[0][0]',
#                                                                   'block1c_add[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 32, 32, 192)  6144        ['block1d_add[0][0]']
#
#  block2a_expand_bn (BatchNormal  (None, 32, 32, 192)  768        ['block2a_expand_conv[0][0]']
#  ization)
#
#  block2a_expand_activation (Act  (None, 32, 32, 192)  0          ['block2a_expand_bn[0][0]']
#  ivation)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 33, 33, 192)  0          ['block2a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 16, 16, 192)  1728       ['block2a_dwconv_pad[0][0]']
#  D)
#
#  block2a_bn (BatchNormalization  (None, 16, 16, 192)  768        ['block2a_dwconv[0][0]']
#  )
#
#  block2a_activation (Activation  (None, 16, 16, 192)  0          ['block2a_bn[0][0]']
#  )
#
#  block2a_se_squeeze (GlobalAver  (None, 192)         0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 16, 16, 192)  0           ['block2a_activation[0][0]',
#                                                                   'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 16, 16, 48)   9216        ['block2a_se_excite[0][0]']
#
#  block2a_project_bn (BatchNorma  (None, 16, 16, 48)  192         ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 16, 16, 288)  13824       ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 16, 16, 288)  1152       ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 16, 16, 288)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_dwconv (DepthwiseConv2  (None, 16, 16, 288)  2592       ['block2b_expand_activation[0][0]
#  D)                                                              ']
#
#  block2b_bn (BatchNormalization  (None, 16, 16, 288)  1152       ['block2b_dwconv[0][0]']
#  )
#
#  block2b_activation (Activation  (None, 16, 16, 288)  0          ['block2b_bn[0][0]']
#  )
#
#  block2b_se_squeeze (GlobalAver  (None, 288)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 16, 16, 288)  0           ['block2b_activation[0][0]',
#                                                                   'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 16, 16, 48)   13824       ['block2b_se_excite[0][0]']
#
#  block2b_project_bn (BatchNorma  (None, 16, 16, 48)  192         ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 16, 16, 48)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 16, 16, 48)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 16, 16, 288)  13824       ['block2b_add[0][0]']
#
#  block2c_expand_bn (BatchNormal  (None, 16, 16, 288)  1152       ['block2c_expand_conv[0][0]']
#  ization)
#
#  block2c_expand_activation (Act  (None, 16, 16, 288)  0          ['block2c_expand_bn[0][0]']
#  ivation)
#
#  block2c_dwconv (DepthwiseConv2  (None, 16, 16, 288)  2592       ['block2c_expand_activation[0][0]
#  D)                                                              ']
#
#  block2c_bn (BatchNormalization  (None, 16, 16, 288)  1152       ['block2c_dwconv[0][0]']
#  )
#
#  block2c_activation (Activation  (None, 16, 16, 288)  0          ['block2c_bn[0][0]']
#  )
#
#  block2c_se_squeeze (GlobalAver  (None, 288)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 16, 16, 288)  0           ['block2c_activation[0][0]',
#                                                                   'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 16, 16, 48)   13824       ['block2c_se_excite[0][0]']
#
#  block2c_project_bn (BatchNorma  (None, 16, 16, 48)  192         ['block2c_project_conv[0][0]']
#  lization)
#
#  block2c_drop (Dropout)         (None, 16, 16, 48)   0           ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)              (None, 16, 16, 48)   0           ['block2c_drop[0][0]',
#                                                                   'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 16, 16, 288)  13824       ['block2c_add[0][0]']
#
#  block2d_expand_bn (BatchNormal  (None, 16, 16, 288)  1152       ['block2d_expand_conv[0][0]']
#  ization)
#
#  block2d_expand_activation (Act  (None, 16, 16, 288)  0          ['block2d_expand_bn[0][0]']
#  ivation)
#
#  block2d_dwconv (DepthwiseConv2  (None, 16, 16, 288)  2592       ['block2d_expand_activation[0][0]
#  D)                                                              ']
#
#  block2d_bn (BatchNormalization  (None, 16, 16, 288)  1152       ['block2d_dwconv[0][0]']
#  )
#
#  block2d_activation (Activation  (None, 16, 16, 288)  0          ['block2d_bn[0][0]']
#  )
#
#  block2d_se_squeeze (GlobalAver  (None, 288)         0           ['block2d_activation[0][0]']
#  agePooling2D)
#
#  block2d_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2d_se_squeeze[0][0]']
#
#  block2d_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multiply)   (None, 16, 16, 288)  0           ['block2d_activation[0][0]',
#                                                                   'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv2D)  (None, 16, 16, 48)   13824       ['block2d_se_excite[0][0]']
#
#  block2d_project_bn (BatchNorma  (None, 16, 16, 48)  192         ['block2d_project_conv[0][0]']
#  lization)
#
#  block2d_drop (Dropout)         (None, 16, 16, 48)   0           ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)              (None, 16, 16, 48)   0           ['block2d_drop[0][0]',
#                                                                   'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2D)   (None, 16, 16, 288)  13824       ['block2d_add[0][0]']
#
#  block2e_expand_bn (BatchNormal  (None, 16, 16, 288)  1152       ['block2e_expand_conv[0][0]']
#  ization)
#
#  block2e_expand_activation (Act  (None, 16, 16, 288)  0          ['block2e_expand_bn[0][0]']
#  ivation)
#
#  block2e_dwconv (DepthwiseConv2  (None, 16, 16, 288)  2592       ['block2e_expand_activation[0][0]
#  D)                                                              ']
#
#  block2e_bn (BatchNormalization  (None, 16, 16, 288)  1152       ['block2e_dwconv[0][0]']
#  )
#
#  block2e_activation (Activation  (None, 16, 16, 288)  0          ['block2e_bn[0][0]']
#  )
#
#  block2e_se_squeeze (GlobalAver  (None, 288)         0           ['block2e_activation[0][0]']
#  agePooling2D)
#
#  block2e_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2e_se_squeeze[0][0]']
#
#  block2e_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2e_se_reshape[0][0]']
#
#  block2e_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2e_se_reduce[0][0]']
#
#  block2e_se_excite (Multiply)   (None, 16, 16, 288)  0           ['block2e_activation[0][0]',
#                                                                   'block2e_se_expand[0][0]']
#
#  block2e_project_conv (Conv2D)  (None, 16, 16, 48)   13824       ['block2e_se_excite[0][0]']
#
#  block2e_project_bn (BatchNorma  (None, 16, 16, 48)  192         ['block2e_project_conv[0][0]']
#  lization)
#
#  block2e_drop (Dropout)         (None, 16, 16, 48)   0           ['block2e_project_bn[0][0]']
#
#  block2e_add (Add)              (None, 16, 16, 48)   0           ['block2e_drop[0][0]',
#                                                                   'block2d_add[0][0]']
#
#  block2f_expand_conv (Conv2D)   (None, 16, 16, 288)  13824       ['block2e_add[0][0]']
#
#  block2f_expand_bn (BatchNormal  (None, 16, 16, 288)  1152       ['block2f_expand_conv[0][0]']
#  ization)
#
#  block2f_expand_activation (Act  (None, 16, 16, 288)  0          ['block2f_expand_bn[0][0]']
#  ivation)
#
#  block2f_dwconv (DepthwiseConv2  (None, 16, 16, 288)  2592       ['block2f_expand_activation[0][0]
#  D)                                                              ']
#
#  block2f_bn (BatchNormalization  (None, 16, 16, 288)  1152       ['block2f_dwconv[0][0]']
#  )
#
#  block2f_activation (Activation  (None, 16, 16, 288)  0          ['block2f_bn[0][0]']
#  )
#
#  block2f_se_squeeze (GlobalAver  (None, 288)         0           ['block2f_activation[0][0]']
#  agePooling2D)
#
#  block2f_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2f_se_squeeze[0][0]']
#
#  block2f_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2f_se_reshape[0][0]']
#
#  block2f_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2f_se_reduce[0][0]']
#
#  block2f_se_excite (Multiply)   (None, 16, 16, 288)  0           ['block2f_activation[0][0]',
#                                                                   'block2f_se_expand[0][0]']
#
#  block2f_project_conv (Conv2D)  (None, 16, 16, 48)   13824       ['block2f_se_excite[0][0]']
#
#  block2f_project_bn (BatchNorma  (None, 16, 16, 48)  192         ['block2f_project_conv[0][0]']
#  lization)
#
#  block2f_drop (Dropout)         (None, 16, 16, 48)   0           ['block2f_project_bn[0][0]']
#
#  block2f_add (Add)              (None, 16, 16, 48)   0           ['block2f_drop[0][0]',
#                                                                   'block2e_add[0][0]']
#
#  block2g_expand_conv (Conv2D)   (None, 16, 16, 288)  13824       ['block2f_add[0][0]']
#
#  block2g_expand_bn (BatchNormal  (None, 16, 16, 288)  1152       ['block2g_expand_conv[0][0]']
#  ization)
#
#  block2g_expand_activation (Act  (None, 16, 16, 288)  0          ['block2g_expand_bn[0][0]']
#  ivation)
#
#  block2g_dwconv (DepthwiseConv2  (None, 16, 16, 288)  2592       ['block2g_expand_activation[0][0]
#  D)                                                              ']
#
#  block2g_bn (BatchNormalization  (None, 16, 16, 288)  1152       ['block2g_dwconv[0][0]']
#  )
#
#  block2g_activation (Activation  (None, 16, 16, 288)  0          ['block2g_bn[0][0]']
#  )
#
#  block2g_se_squeeze (GlobalAver  (None, 288)         0           ['block2g_activation[0][0]']
#  agePooling2D)
#
#  block2g_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2g_se_squeeze[0][0]']
#
#  block2g_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2g_se_reshape[0][0]']
#
#  block2g_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2g_se_reduce[0][0]']
#
#  block2g_se_excite (Multiply)   (None, 16, 16, 288)  0           ['block2g_activation[0][0]',
#                                                                   'block2g_se_expand[0][0]']
#
#  block2g_project_conv (Conv2D)  (None, 16, 16, 48)   13824       ['block2g_se_excite[0][0]']
#
#  block2g_project_bn (BatchNorma  (None, 16, 16, 48)  192         ['block2g_project_conv[0][0]']
#  lization)
#
#  block2g_drop (Dropout)         (None, 16, 16, 48)   0           ['block2g_project_bn[0][0]']
#
#  block2g_add (Add)              (None, 16, 16, 48)   0           ['block2g_drop[0][0]',
#                                                                   'block2f_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 16, 16, 288)  13824       ['block2g_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 16, 16, 288)  1152       ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 16, 16, 288)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 19, 19, 288)  0          ['block3a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 8, 8, 288)   7200        ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 8, 8, 288)   1152        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 8, 8, 288)   0           ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 288)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 8, 8, 288)    0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 8, 8, 80)     23040       ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 8, 8, 80)    320         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 8, 8, 480)    38400       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 8, 8, 480)   1920        ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 8, 8, 480)   0           ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 8, 8, 480)   12000       ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 8, 8, 480)   1920        ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 8, 8, 480)   0           ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 480)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 480)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 20)     9620        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 480)    10080       ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 8, 8, 480)    0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 8, 8, 80)     38400       ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 8, 8, 80)    320         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 8, 8, 80)     0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 8, 8, 80)     0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
# ...
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 2304)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 96)     221280      ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 2304)   223488      ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 2, 2, 2304)   0           ['block7a_activation[0][0]',
#                                                                   'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 2, 2, 640)    1474560     ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 2, 2, 640)   2560        ['block7a_project_conv[0][0]']
#  lization)
#
#  block7b_expand_conv (Conv2D)   (None, 2, 2, 3840)   2457600     ['block7a_project_bn[0][0]']
#
#  block7b_expand_bn (BatchNormal  (None, 2, 2, 3840)  15360       ['block7b_expand_conv[0][0]']
#  ization)
#
#  block7b_expand_activation (Act  (None, 2, 2, 3840)  0           ['block7b_expand_bn[0][0]']
#  ivation)
#
#  block7b_dwconv (DepthwiseConv2  (None, 2, 2, 3840)  34560       ['block7b_expand_activation[0][0]
#  D)                                                              ']
#
#  block7b_bn (BatchNormalization  (None, 2, 2, 3840)  15360       ['block7b_dwconv[0][0]']
#  )
#
#  block7b_activation (Activation  (None, 2, 2, 3840)  0           ['block7b_bn[0][0]']
#  )
#
#  block7b_se_squeeze (GlobalAver  (None, 3840)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 3840)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 160)    614560      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 3840)   618240      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 2, 2, 3840)   0           ['block7b_activation[0][0]',
#                                                                   'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 2, 2, 640)    2457600     ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 2, 2, 640)   2560        ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_drop (Dropout)         (None, 2, 2, 640)    0           ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)              (None, 2, 2, 640)    0           ['block7b_drop[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  block7c_expand_conv (Conv2D)   (None, 2, 2, 3840)   2457600     ['block7b_add[0][0]']
#
#  block7c_expand_bn (BatchNormal  (None, 2, 2, 3840)  15360       ['block7c_expand_conv[0][0]']
#  ization)
#
#  block7c_expand_activation (Act  (None, 2, 2, 3840)  0           ['block7c_expand_bn[0][0]']
#  ivation)
#
#  block7c_dwconv (DepthwiseConv2  (None, 2, 2, 3840)  34560       ['block7c_expand_activation[0][0]
#  D)                                                              ']
#
#  block7c_bn (BatchNormalization  (None, 2, 2, 3840)  15360       ['block7c_dwconv[0][0]']
#  )
#
#  block7c_activation (Activation  (None, 2, 2, 3840)  0           ['block7c_bn[0][0]']
#  )
#
#  block7c_se_squeeze (GlobalAver  (None, 3840)        0           ['block7c_activation[0][0]']
#  agePooling2D)
#
#  block7c_se_reshape (Reshape)   (None, 1, 1, 3840)   0           ['block7c_se_squeeze[0][0]']
#
#  block7c_se_reduce (Conv2D)     (None, 1, 1, 160)    614560      ['block7c_se_reshape[0][0]']
#
#  block7c_se_expand (Conv2D)     (None, 1, 1, 3840)   618240      ['block7c_se_reduce[0][0]']
#
#  block7c_se_excite (Multiply)   (None, 2, 2, 3840)   0           ['block7c_activation[0][0]',
#                                                                   'block7c_se_expand[0][0]']
#
#  block7c_project_conv (Conv2D)  (None, 2, 2, 640)    2457600     ['block7c_se_excite[0][0]']
#
#  block7c_project_bn (BatchNorma  (None, 2, 2, 640)   2560        ['block7c_project_conv[0][0]']
#  lization)
#
#  block7c_drop (Dropout)         (None, 2, 2, 640)    0           ['block7c_project_bn[0][0]']
#
#  block7c_add (Add)              (None, 2, 2, 640)    0           ['block7c_drop[0][0]',
#                                                                   'block7b_add[0][0]']
#
#  block7d_expand_conv (Conv2D)   (None, 2, 2, 3840)   2457600     ['block7c_add[0][0]']
#
#  block7d_expand_bn (BatchNormal  (None, 2, 2, 3840)  15360       ['block7d_expand_conv[0][0]']
#  ization)
#
#  block7d_expand_activation (Act  (None, 2, 2, 3840)  0           ['block7d_expand_bn[0][0]']
#  ivation)
#
#  block7d_dwconv (DepthwiseConv2  (None, 2, 2, 3840)  34560       ['block7d_expand_activation[0][0]
#  D)                                                              ']
#
#  block7d_bn (BatchNormalization  (None, 2, 2, 3840)  15360       ['block7d_dwconv[0][0]']
#  )
#
#  block7d_activation (Activation  (None, 2, 2, 3840)  0           ['block7d_bn[0][0]']
#  )
#
#  block7d_se_squeeze (GlobalAver  (None, 3840)        0           ['block7d_activation[0][0]']
#  agePooling2D)
#
#  block7d_se_reshape (Reshape)   (None, 1, 1, 3840)   0           ['block7d_se_squeeze[0][0]']
#
#  block7d_se_reduce (Conv2D)     (None, 1, 1, 160)    614560      ['block7d_se_reshape[0][0]']
#
#  block7d_se_expand (Conv2D)     (None, 1, 1, 3840)   618240      ['block7d_se_reduce[0][0]']
#
#  block7d_se_excite (Multiply)   (None, 2, 2, 3840)   0           ['block7d_activation[0][0]',
#                                                                   'block7d_se_expand[0][0]']
#
#  block7d_project_conv (Conv2D)  (None, 2, 2, 640)    2457600     ['block7d_se_excite[0][0]']
#
#  block7d_project_bn (BatchNorma  (None, 2, 2, 640)   2560        ['block7d_project_conv[0][0]']
#  lization)
#
#  block7d_drop (Dropout)         (None, 2, 2, 640)    0           ['block7d_project_bn[0][0]']
#
#  block7d_add (Add)              (None, 2, 2, 640)    0           ['block7d_drop[0][0]',
#                                                                   'block7c_add[0][0]']
#
#  top_conv (Conv2D)              (None, 2, 2, 2560)   1638400     ['block7d_add[0][0]']
#
#  top_bn (BatchNormalization)    (None, 2, 2, 2560)   10240       ['top_conv[0][0]']
#
#  top_activation (Activation)    (None, 2, 2, 2560)   0           ['top_bn[0][0]']
#
#  flatten_4 (Flatten)            (None, 10240)        0           ['top_activation[0][0]']
#
#  dense_5 (Dense)                (None, 512)          5243392     ['flatten_4[0][0]']
#
#  dense_6 (Dense)                (None, 2)            1026        ['dense_5[0][0]']
#
# ==================================================================================================
# Total params: 69,342,105
# Trainable params: 69,031,378
# Non-trainable params: 310,727
# __________________________________________________________________________________________________
# Epoch 1/50
# 139/139 [==============================] - 75s 297ms/step - loss: 0.6624 - accuracy: 0.7014 - val_loss: 0.8721 - val_accuracy: 0.4901
# Epoch 2/50
# 139/139 [==============================] - 34s 244ms/step - loss: 0.4417 - accuracy: 0.7969 - val_loss: 0.7561 - val_accuracy: 0.5126
# Epoch 3/50
# 139/139 [==============================] - 33s 240ms/step - loss: 0.3741 - accuracy: 0.8402 - val_loss: 0.7773 - val_accuracy: 0.5000
# Epoch 4/50
# 139/139 [==============================] - 34s 245ms/step - loss: 0.3184 - accuracy: 0.8636 - val_loss: 0.7225 - val_accuracy: 0.6171
# Epoch 5/50
# 139/139 [==============================] - 34s 244ms/step - loss: 0.2326 - accuracy: 0.9087 - val_loss: 1.0643 - val_accuracy: 0.5009
# Epoch 6/50
# 139/139 [==============================] - 34s 244ms/step - loss: 0.1910 - accuracy: 0.9286 - val_loss: 0.7606 - val_accuracy: 0.5667
# Epoch 7/50
# 139/139 [==============================] - 34s 243ms/step - loss: 0.1583 - accuracy: 0.9405 - val_loss: 1.3901 - val_accuracy: 0.5279
# Epoch 8/50
# 139/139 [==============================] - 34s 244ms/step - loss: 0.1365 - accuracy: 0.9509 - val_loss: 1.4611 - val_accuracy: 0.5063
# Epoch 9/50
# 139/139 [==============================] - 34s 243ms/step - loss: 0.1165 - accuracy: 0.9572 - val_loss: 1.0242 - val_accuracy: 0.5441

# %%
# test the classifier model:
preds=model.predict(X_test)
preds
# Out:
# array([[0.05724655, 0.94275343],
#        [0.6598962 , 0.34010378],
#        [0.01580467, 0.98419535],
#        ...,
#        [0.05901439, 0.94098556],
#        [0.10620005, 0.8938    ],
#        [0.585201  , 0.41479897]], dtype=float32)

# %%
y_test_arg=np.argmax(y_test,axis=1)
Y_pred = np.argmax(preds,axis=1)
print(confusion_matrix(y_test_arg, Y_pred))
print(classification_report(y_test_arg, Y_pred))
# Out:
# [[198 368]
#  [138 406]]
#               precision    recall  f1-score   support
#
#            0       0.59      0.35      0.44       566
#            1       0.52      0.75      0.62       544
#
#     accuracy                           0.54      1110
#    macro avg       0.56      0.55      0.53      1110
# weighted avg       0.56      0.54      0.53      1110

# %%
# summarize history for accuracy
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
RestNet50=tf.keras.applications.resnet.ResNet50(input_shape=(64,64,3),
                                               include_top=False,
                                               weights='imagenet')
mod1=RestNet50.output
mod1=tf.keras.layers.Flatten()(mod1)
mod1=tf.keras.layers.Dense(units=256, activation=tf.nn.relu)(mod1)
output1=tf.keras.layers.Dense(units=2, activation=tf.nn.sigmoid)(mod1)
model10= tf.keras.models.Model(inputs=RestNet50.inputs,outputs=output1)

model10.compile(optimizer=tf.keras.optimizers.Adam(0.001),
             loss=tf.keras.losses.BinaryCrossentropy(from_logits= False),
             metrics=['accuracy'])
model10.summary()

callback = EarlyStopping(monitor='val_accuracy', patience=5)

seed = 1234
np.random.seed(seed)
hist10 = model10.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=32, callbacks=[callback])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 0s 0us/step
# 94781440/94765736 [==============================] - 0s 0us/step
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  conv1_pad (ZeroPadding2D)      (None, 70, 70, 3)    0           ['input_2[0][0]']
#
#  conv1_conv (Conv2D)            (None, 32, 32, 64)   9472        ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalization)  (None, 32, 32, 64)   256         ['conv1_conv[0][0]']
#
#  conv1_relu (Activation)        (None, 32, 32, 64)   0           ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 34, 34, 64)   0           ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 16, 16, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 16, 16, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 16, 16, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 16, 16, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 16, 16, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 16, 16, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 16, 16, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 16, 16, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 16, 16, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 16, 16, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 16, 16, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 16, 16, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 16, 16, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 16, 16, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 16, 16, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 16, 16, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 16, 16, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 16, 16, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 16, 16, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 16, 16, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 16, 16, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 16, 16, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 16, 16, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 16, 16, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 16, 16, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 16, 16, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 16, 16, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 16, 16, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 16, 16, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 8, 8, 128)    32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 8, 8, 128)    147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 8, 8, 128)   0           ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 8, 8, 512)    131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 8, 8, 512)    66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 8, 8, 512)    0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 8, 8, 512)    0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 8, 8, 128)    65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 8, 8, 128)    147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 8, 8, 128)   0           ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 8, 8, 512)    66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 8, 8, 512)    0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 8, 8, 512)    0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 8, 8, 128)    65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 8, 8, 128)    147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 8, 8, 128)   0           ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 8, 8, 512)    66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 8, 8, 512)    0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 8, 8, 512)    0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 8, 8, 128)    65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 8, 8, 128)    147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 8, 8, 128)   0           ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 8, 8, 512)    66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 8, 8, 512)    0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 8, 8, 512)    0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 4, 4, 256)    131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 4, 4, 256)   1024        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 4, 4, 256)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 4, 4, 256)    590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 4, 4, 256)   1024        ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 4, 4, 256)   0           ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 4, 4, 1024)   525312      ['conv3_block4_out[0][0]']
#
#  conv4_block1_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      ['conv4_block1_2_relu[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 4, 4, 1024)  4096        ['conv4_block1_0_conv[0][0]']
#  ization)
#
#  conv4_block1_3_bn (BatchNormal  (None, 4, 4, 1024)  4096        ['conv4_block1_3_conv[0][0]']
#  ization)
#
#  conv4_block1_add (Add)         (None, 4, 4, 1024)   0           ['conv4_block1_0_bn[0][0]',
#                                                                   'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 4, 4, 1024)   0           ['conv4_block1_add[0][0]']
#
#  conv4_block2_1_conv (Conv2D)   (None, 4, 4, 256)    262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 4, 4, 256)   1024        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 4, 4, 256)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 4, 4, 256)    590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 4, 4, 256)   1024        ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 4, 4, 256)   0           ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      ['conv4_block2_2_relu[0][0]']
#
#  conv4_block2_3_bn (BatchNormal  (None, 4, 4, 1024)  4096        ['conv4_block2_3_conv[0][0]']
#  ization)
#
#  conv4_block2_add (Add)         (None, 4, 4, 1024)   0           ['conv4_block1_out[0][0]',
#                                                                   'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 4, 4, 1024)   0           ['conv4_block2_add[0][0]']
#
#  conv4_block3_1_conv (Conv2D)   (None, 4, 4, 256)    262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 4, 4, 256)   1024        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 4, 4, 256)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 4, 4, 256)    590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 4, 4, 256)   1024        ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 4, 4, 256)   0           ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      ['conv4_block3_2_relu[0][0]']
#
#  conv4_block3_3_bn (BatchNormal  (None, 4, 4, 1024)  4096        ['conv4_block3_3_conv[0][0]']
#  ization)
#
#  conv4_block3_add (Add)         (None, 4, 4, 1024)   0           ['conv4_block2_out[0][0]',
#                                                                   'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 4, 4, 1024)   0           ['conv4_block3_add[0][0]']
#
#  conv4_block4_1_conv (Conv2D)   (None, 4, 4, 256)    262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 4, 4, 256)   1024        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 4, 4, 256)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 4, 4, 256)    590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 4, 4, 256)   1024        ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 4, 4, 256)   0           ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      ['conv4_block4_2_relu[0][0]']
#
#  conv4_block4_3_bn (BatchNormal  (None, 4, 4, 1024)  4096        ['conv4_block4_3_conv[0][0]']
#  ization)
#
#  conv4_block4_add (Add)         (None, 4, 4, 1024)   0           ['conv4_block3_out[0][0]',
#                                                                   'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 4, 4, 1024)   0           ['conv4_block4_add[0][0]']
#
#  conv4_block5_1_conv (Conv2D)   (None, 4, 4, 256)    262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 4, 4, 256)   1024        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 4, 4, 256)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 4, 4, 256)    590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 4, 4, 256)   1024        ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 4, 4, 256)   0           ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      ['conv4_block5_2_relu[0][0]']
#
#  conv4_block5_3_bn (BatchNormal  (None, 4, 4, 1024)  4096        ['conv4_block5_3_conv[0][0]']
#  ization)
#
#  conv4_block5_add (Add)         (None, 4, 4, 1024)   0           ['conv4_block4_out[0][0]',
#                                                                   'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 4, 4, 1024)   0           ['conv4_block5_add[0][0]']
#
#  conv4_block6_1_conv (Conv2D)   (None, 4, 4, 256)    262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 4, 4, 256)   1024        ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 4, 4, 256)   0           ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 4, 4, 256)    590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 4, 4, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 4, 4, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_3_bn (BatchNormal  (None, 4, 4, 1024)  4096        ['conv4_block6_3_conv[0][0]']
#  ization)
#
#  conv4_block6_add (Add)         (None, 4, 4, 1024)   0           ['conv4_block5_out[0][0]',
#                                                                   'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 4, 4, 1024)   0           ['conv4_block6_add[0][0]']
#
#  conv5_block1_1_conv (Conv2D)   (None, 2, 2, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 2, 2, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 2, 2, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 2, 2, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 2, 2, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 2, 2, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 2, 2, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 2, 2, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 2, 2, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 2, 2, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 2, 2, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 2, 2, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 2, 2, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 2, 2, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 2, 2, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 2, 2, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 2, 2, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 2, 2, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 2, 2, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 2, 2, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 2, 2, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 2, 2, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 2, 2, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 2, 2, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 2, 2, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 2, 2, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 2, 2, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 2, 2, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 2, 2, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 2, 2, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 2, 2, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 2, 2, 2048)   0           ['conv5_block3_add[0][0]']
#
#  flatten_5 (Flatten)            (None, 8192)         0           ['conv5_block3_out[0][0]']
#
#  dense_7 (Dense)                (None, 256)          2097408     ['flatten_5[0][0]']
#
#  dense_8 (Dense)                (None, 2)            514         ['dense_7[0][0]']
#
# ==================================================================================================
# Total params: 25,685,634
# Trainable params: 25,632,514
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# Epoch 1/50
# 139/139 [==============================] - 18s 80ms/step - loss: 0.6328 - accuracy: 0.7446 - val_loss: 0.6931 - val_accuracy: 0.5099
# Epoch 2/50
# 139/139 [==============================] - 9s 65ms/step - loss: 0.4762 - accuracy: 0.7918 - val_loss: 0.6930 - val_accuracy: 0.5099
# Epoch 3/50
# 139/139 [==============================] - 9s 65ms/step - loss: 0.4495 - accuracy: 0.8059 - val_loss: 0.6930 - val_accuracy: 0.5099
# Epoch 4/50
# 139/139 [==============================] - 9s 65ms/step - loss: 0.4063 - accuracy: 0.8208 - val_loss: 0.6880 - val_accuracy: 0.6009
# Epoch 5/50
# 139/139 [==============================] - 9s 65ms/step - loss: 0.4249 - accuracy: 0.8093 - val_loss: 0.6827 - val_accuracy: 0.5766
# Epoch 6/50
# 139/139 [==============================] - 9s 65ms/step - loss: 0.3975 - accuracy: 0.8305 - val_loss: 0.7785 - val_accuracy: 0.4910
# Epoch 7/50
# 139/139 [==============================] - 9s 64ms/step - loss: 0.3360 - accuracy: 0.8591 - val_loss: 0.5348 - val_accuracy: 0.7550
# Epoch 8/50
# 139/139 [==============================] - 9s 63ms/step - loss: 0.2767 - accuracy: 0.8884 - val_loss: 0.6054 - val_accuracy: 0.7423
# Epoch 9/50
# 139/139 [==============================] - 9s 64ms/step - loss: 0.2333 - accuracy: 0.9058 - val_loss: 2.1499 - val_accuracy: 0.5252
# Epoch 10/50
# 139/139 [==============================] - 9s 64ms/step - loss: 0.2238 - accuracy: 0.9089 - val_loss: 0.7956 - val_accuracy: 0.7324
# Epoch 11/50
# 139/139 [==============================] - 9s 64ms/step - loss: 0.1822 - accuracy: 0.9272 - val_loss: 0.8424 - val_accuracy: 0.7387
# Epoch 12/50
# 139/139 [==============================] - 9s 64ms/step - loss: 0.1383 - accuracy: 0.9493 - val_loss: 1.0366 - val_accuracy: 0.7216

# %%
# test the classifier model:
preds=model10.predict(X_test)
preds
# Out:
# array([[0.8760093 , 0.11721327],
#        [0.04025989, 0.96268755],
#        [0.9174674 , 0.08125699],
#        ...,
#        [0.95347226, 0.04502394],
#        [0.8474221 , 0.15544905],
#        [0.02482027, 0.97943306]], dtype=float32)

# %%
y_test_arg=np.argmax(y_test,axis=1)
Y_pred = np.argmax(preds,axis=1)
print(confusion_matrix(y_test_arg, Y_pred))
print(classification_report(y_test_arg, Y_pred))
# Out:
# [[498  68]
#  [241 303]]
#               precision    recall  f1-score   support
#
#            0       0.67      0.88      0.76       566
#            1       0.82      0.56      0.66       544
#
#     accuracy                           0.72      1110
#    macro avg       0.75      0.72      0.71      1110
# weighted avg       0.74      0.72      0.71      1110

# %%
plt.plot(hist10.history['accuracy'])
plt.plot(hist10.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(hist10.history['loss'])
plt.plot(hist10.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
